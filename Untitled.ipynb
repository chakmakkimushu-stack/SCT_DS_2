# %%
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

df['Age'] = df['Age'].fillna(df['Age'].median())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])
df.drop(columns=['Cabin', 'Name', 'Ticket'], inplace=True)

print("--- TITANIC SURVIVAL VALUES ---\n")

print("Survival by Gender:")
print(df.groupby('Sex')['Survived'].mean().round(4) * 100)

print("\nSurvival by Passenger Class:")
print(df.groupby('Pclass')['Survived'].mean().round(4) * 100)

print("\nNumerical Correlation with Survival:")
numeric_df = df.select_dtypes(include=['number'])
print(numeric_df.corr()['Survived'].sort_values(ascending=False))
# Out:
# --- TITANIC SURVIVAL VALUES ---
#
# Survival by Gender:
# Sex
# female    74.20
# male      18.89
# Name: Survived, dtype: float64
#
# Survival by Passenger Class:
# Pclass
# 1    62.96
# 2    47.28
# 3    24.24
# Name: Survived, dtype: float64
#
# Numerical Correlation with Survival:
# Survived       1.000000
# Fare           0.257307
# Parch          0.081629
# PassengerId   -0.005007
# SibSp         -0.035322
# Age           -0.064910
# Pclass        -0.338481
# Name: Survived, dtype: float64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(16, 10))
sns.set_style("whitegrid")

plt.subplot(2, 2, 1)
sns.barplot(x='Sex', y='Survived', data=df, hue='Sex', palette='RdBu_r', legend=False)
plt.title('Survival Rate: Female vs Male')

plt.subplot(2, 2, 2)
sns.countplot(x='Pclass', hue='Survived', data=df, palette='viridis')
plt.title('Survival Count by Ticket Class')

plt.subplot(2, 2, 3)
sns.kdeplot(data=df, x='Age', hue='Survived', fill=True, common_norm=False, palette='crest')
plt.title('Age Density: Survivors vs Victims')

plt.subplot(2, 2, 4)
numeric_df = df.select_dtypes(include=['number'])
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Feature Correlation Heatmap')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

df['Age'] = df['Age'].fillna(df['Age'].median())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])
df.drop(columns=['Cabin'], inplace=True)

plt.figure(figsize=(16, 10))
sns.set_style("whitegrid")

plt.subplot(2, 2, 1)
sns.barplot(x='Sex', y='Survived', data=df, hue='Sex', palette='magma', legend=False)
plt.title('Survival Rate: Female vs Male')

plt.subplot(2, 2, 2)
sns.countplot(x='Pclass', hue='Survived', data=df, palette='viridis')
plt.title('Survival Count by Ticket Class')

plt.subplot(2, 2, 3)
sns.histplot(data=df, x='Age', hue='Survived', multiple='stack', kde=True, palette='crest')
plt.title('Survival Distribution by Age')

plt.subplot(2, 2, 4)
# Out:
# <Axes: >
